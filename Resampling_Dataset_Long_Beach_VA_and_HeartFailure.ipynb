# %% [markdown]
# <a href="https://colab.research.google.com/github/Krisnaaassss/heart-disease-classification-bayesian-soft-voting/blob/main/Resampling_Dataset_Long_Beach_VA_and_HeartFailure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Setup and Configuration

# %% [markdown]
# ## 1.1 Library Installation and Imports

# %%
# CELL 1 — Install and Import
# !pip install xgboost lightgbm imbalanced-learn scikit-optimize -q

import warnings
warnings.filterwarnings("ignore", category=UserWarning)

import pandas as pd
import numpy as np
from collections import Counter

from sklearn.model_selection import (StratifiedKFold, cross_validate,
                                      GridSearchCV, RandomizedSearchCV)
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.metrics import (make_scorer, precision_score, recall_score, f1_score,
                             accuracy_score, roc_auc_score)
from sklearn.ensemble import VotingClassifier
from sklearn.base import BaseEstimator, ClassifierMixin, clone

from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
import xgboost as xgb
import lightgbm as lgb

from imblearn.over_sampling import SMOTE, BorderlineSMOTE
from imblearn.combine import SMOTETomek
from imblearn.pipeline import Pipeline as ImbPipeline

from skopt import BayesSearchCV, gp_minimize
from skopt.space import Real, Integer, Categorical

print('Libraries loaded successfully.')
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 4.5 MB/s eta 0:00:00
# Libraries loaded successfully.

# %% [markdown]
# ## 1.2 Global Configuration

# %%
# CELL 2 — Global Configuration

RANDOM_STATE = 42
N_OUTER_FOLDS = 5
N_INNER_FOLDS = 5

IMBALANCED_DATASETS = {'Framingham', 'Heart Failure Clinical', 'Switzerland'}

SCORING = {
    'accuracy':  'accuracy',
    'precision': make_scorer(precision_score, zero_division=0),
    'recall':    make_scorer(recall_score,    zero_division=0),
    'f1':        make_scorer(f1_score,        zero_division=0),
    'roc_auc':   'roc_auc',
}


RESAMPLING_METHODS = [
    'none',
    'smote',
    'borderline_smote',
    'smote_tomek',
]

def get_resampler(resampling_method):
    if resampling_method == 'none':
        return None
    if resampling_method == 'smote':
        return SMOTE(random_state=RANDOM_STATE, k_neighbors=5)
    if resampling_method == 'borderline_smote':
        return BorderlineSMOTE(
            random_state=RANDOM_STATE,
            kind='borderline-1',
            k_neighbors=5,
            m_neighbors=10,
        )
    if resampling_method == 'smote_tomek':
        return SMOTETomek(
            random_state=RANDOM_STATE,
            smote=SMOTE(random_state=RANDOM_STATE, k_neighbors=5),
        )
    raise ValueError(
        "resampling_method harus 'none', 'smote', "
        "'borderline_smote', atau 'smote_tomek'."
    )

def get_resampling_label(resampling_method):
    labels = {
        'none': 'No Resampling',
        'smote': 'SMOTE',
        'borderline_smote': 'Borderline-SMOTE',
        'smote_tomek': 'SMOTE-Tomek',
    }
    return labels[resampling_method]

print('Global configuration completed.')
# Out:
# Global configuration completed.

# %% [markdown]
# # 2. Main Evaluation Pipeline

# %% [markdown]
# ## 2.1 Bayesian Optimization for Baseline Models

# %%
# CELL 4 — Baseline Models with Bayesian Optimization

def _build_models_and_spaces():
    return {
        'SVM': (
            SVC(probability=True, random_state=RANDOM_STATE),
            {'model__C':      Real(1e-2, 1e2, prior='log-uniform'),
             'model__kernel': Categorical(['rbf', 'linear'])},
        ),
        'Naive Bayes': (
            GaussianNB(),
            {'model__var_smoothing': Real(1e-10, 1e-6, prior='log-uniform')},
        ),
        'Random Forest': (
            RandomForestClassifier(random_state=RANDOM_STATE, n_jobs=1),
            {'model__n_estimators': Integer(50, 300),
             'model__max_depth':    Integer(3, 30)},
        ),
        'J48 (DecTree)': (
            DecisionTreeClassifier(random_state=RANDOM_STATE),
            {'model__max_depth':  Integer(2, 20),
             'model__criterion':  Categorical(['gini', 'entropy'])},
        ),
        'Logistic Regression': (
            LogisticRegression(max_iter=1000, random_state=RANDOM_STATE),
            {'model__C': Real(1e-2, 1e2, prior='log-uniform')},
        ),
        'XGBoost': (
            xgb.XGBClassifier(random_state=RANDOM_STATE, eval_metric='logloss', n_jobs=1),
            {'model__n_estimators':  Integer(50, 300),
             'model__max_depth':     Integer(2, 10),
             'model__learning_rate': Real(1e-2, 3e-1, prior='log-uniform')},
        ),
        'LightGBM': (
            lgb.LGBMClassifier(random_state=RANDOM_STATE, verbose=-1, n_jobs=1),
            {'model__n_estimators':  Integer(50, 500),
             'model__num_leaves':    Integer(7, 150),
             'model__learning_rate': Real(1e-2, 3e-1, prior='log-uniform')},
        ),
        'KNN': (
            KNeighborsClassifier(n_jobs=1),
            {'model__n_neighbors': Integer(3, 15),
             'model__weights':     Categorical(['uniform', 'distance'])},
        ),
    }


def _make_pipe(model, resampling_method='none'):
    resampler = get_resampler(resampling_method)

    if resampler is not None:
        return ImbPipeline([
            ('imputer', SimpleImputer(strategy='median')),
            ('resampler', resampler),
            ('scaler', StandardScaler()),
            ('model', model),
        ])

    return Pipeline([
        ('imputer', SimpleImputer(strategy='median')),
        ('scaler', StandardScaler()),
        ('model', model),
    ])


def run_nested_cv_baseline(X, y, dataset_name='', resampling_method='none', n_bayes_iter=20):
    outer_cv = StratifiedKFold(n_splits=N_OUTER_FOLDS, shuffle=True, random_state=RANDOM_STATE)
    inner_cv = StratifiedKFold(n_splits=N_INNER_FOLDS, shuffle=True, random_state=RANDOM_STATE)

    models = _build_models_and_spaces()

    print(f'\n  Nested 5-Fold CV — Baseline [Bayesian Optimization] [{dataset_name}] | {get_resampling_label(resampling_method)}')
    print(f'  {"Model":<22} {"Acc":>8} {"±":>5} {"Prec":>8} {"Rec":>8} {"F1":>8} {"AUC":>8}')
    print('  ' + '─' * 72)

    results = {}
    for name, (model, space) in models.items():
        pipe = _make_pipe(model, resampling_method)

        bs = BayesSearchCV(
            pipe, search_spaces=space, n_iter=n_bayes_iter,
            cv=inner_cv, scoring='f1', n_jobs=1, refit=True,
            random_state=RANDOM_STATE,
        )

        score = cross_validate(bs, X, y, cv=outer_cv, scoring=SCORING,
                               n_jobs=-1, return_train_score=False)

        acc  = score['test_accuracy']
        prec = score['test_precision']
        rec  = score['test_recall']
        f1v  = score['test_f1']
        auc  = score['test_roc_auc']
        results[name] = {'acc': acc, 'prec': prec, 'rec': rec, 'f1': f1v, 'auc': auc}

        print(f'  {name:<22}'
              f' {acc.mean()*100:>7.2f}%'
              f' ±{acc.std()*100:.2f}'
              f' {prec.mean()*100:>7.2f}%'
              f' {rec.mean()*100:>7.2f}%'
              f' {f1v.mean()*100:>7.2f}%'
              f' {auc.mean()*100:>7.2f}%')

    return results


def get_best_params_for_voting(X, y, dataset_name='', resampling_method='none', n_bayes_iter=25):
    inner_cv = StratifiedKFold(n_splits=N_INNER_FOLDS, shuffle=True, random_state=RANDOM_STATE)

    voting_members = {
        'svm': (
            SVC(probability=True, random_state=RANDOM_STATE),
            {'model__C':      Real(1e-2, 1e2, prior='log-uniform'),
             'model__kernel': Categorical(['rbf', 'linear'])},
        ),
        'rf': (
            RandomForestClassifier(random_state=RANDOM_STATE, n_jobs=1),
            {'model__n_estimators': Integer(50, 300),
             'model__max_depth':    Integer(3, 30)},
        ),
        'lgbm': (
            lgb.LGBMClassifier(random_state=RANDOM_STATE, verbose=-1, n_jobs=1),
            {'model__n_estimators':  Integer(50, 500),
             'model__num_leaves':    Integer(7, 150),
             'model__learning_rate': Real(1e-2, 3e-1, prior='log-uniform')},
        ),
    }

    print(f'\n  Bayesian optimization for Soft Voting base learners [{dataset_name}]')

    best_params = {}
    for key, (model, space) in voting_members.items():
        pipe = _make_pipe(model, resampling_method)
        bs = BayesSearchCV(
            pipe, search_spaces=space, n_iter=n_bayes_iter,
            cv=inner_cv, scoring='f1', n_jobs=-1, refit=True,
            random_state=RANDOM_STATE,
        )
        bs.fit(X, y)
        clean_params = {k.replace('model__', ''): v for k, v in bs.best_params_.items()}
        best_params[key] = clean_params
        print(f'    {key:<6}: {clean_params}  (F1 inner CV = {bs.best_score_*100:.2f}%)')

    return best_params

print('Baseline evaluation functions initialized.')
# Out:
# Baseline evaluation functions initialized.

# %% [markdown]
# ## 2.2 Soft Voting Ensemble

# %%
# CELL 5 — Soft Voting Ensemble


class WeightedSoftVoting(BaseEstimator, ClassifierMixin):

    def __init__(self, svm=None, rf=None, lgbm=None,
                 w_svm=1.0, w_rf=1.0, w_lgbm=1.0):
        self.svm = svm
        self.rf = rf
        self.lgbm = lgbm
        self.w_svm = w_svm
        self.w_rf = w_rf
        self.w_lgbm = w_lgbm

    def fit(self, X, y):
        self.svm_  = clone(self.svm).fit(X, y)
        self.rf_   = clone(self.rf).fit(X, y)
        self.lgbm_ = clone(self.lgbm).fit(X, y)
        self.classes_ = self.svm_.classes_
        return self

    def predict_proba(self, X):
        w = np.array([self.w_svm, self.w_rf, self.w_lgbm], dtype=float)
        w = w / w.sum()
        proba = (w[0] * self.svm_.predict_proba(X)
                 + w[1] * self.rf_.predict_proba(X)
                 + w[2] * self.lgbm_.predict_proba(X))
        return proba

    def predict(self, X):
        proba = self.predict_proba(X)
        return self.classes_[np.argmax(proba, axis=1)]


def _get_oof_base_proba(X_tr, y_tr, best_params, resampling_method, inner_cv):
    X_tr = X_tr.reset_index(drop=True)
    y_tr = pd.Series(np.asarray(y_tr)).reset_index(drop=True)
    n = len(X_tr)

    oof_svm  = np.zeros(n)
    oof_rf   = np.zeros(n)
    oof_lgbm = np.zeros(n)

    for in_idx, val_idx in inner_cv.split(X_tr, y_tr):
        X_in, X_val = X_tr.iloc[in_idx], X_tr.iloc[val_idx]
        y_in, y_val = y_tr.iloc[in_idx], y_tr.iloc[val_idx]

        imputer = SimpleImputer(strategy='median')
        X_in_imp  = imputer.fit_transform(X_in)
        X_val_imp = imputer.transform(X_val)

        X_in_res, y_in_res = X_in_imp, y_in
        resampler = get_resampler(resampling_method)
        if resampler is not None:
            X_in_res, y_in_res = resampler.fit_resample(X_in_imp, y_in)

        scaler = StandardScaler()
        X_in_scaled  = scaler.fit_transform(X_in_res)
        X_val_scaled = scaler.transform(X_val_imp)

        svm  = SVC(probability=True, random_state=RANDOM_STATE,
                   **best_params['svm']).fit(X_in_scaled, y_in_res)
        rf   = RandomForestClassifier(random_state=RANDOM_STATE, n_jobs=1,
                   **best_params['rf']).fit(X_in_scaled, y_in_res)
        lgbm = lgb.LGBMClassifier(random_state=RANDOM_STATE, verbose=-1, n_jobs=1,
                   **best_params['lgbm']).fit(X_in_scaled, y_in_res)

        oof_svm[val_idx]  = svm.predict_proba(X_val_scaled)[:, 1]
        oof_rf[val_idx]   = rf.predict_proba(X_val_scaled)[:, 1]
        oof_lgbm[val_idx] = lgbm.predict_proba(X_val_scaled)[:, 1]

    return oof_svm, oof_rf, oof_lgbm, y_tr.values


def _search_best_weights(oof_svm, oof_rf, oof_lgbm, y_true, n_calls=15):
    space = [
        Real(0.1, 3.0, name='w_svm'),
        Real(0.1, 3.0, name='w_rf'),
        Real(0.1, 3.0, name='w_lgbm'),
    ]

    def objective(params):
        w_svm, w_rf, w_lgbm = params
        w = np.array([w_svm, w_rf, w_lgbm])
        w = w / w.sum()
        proba = w[0] * oof_svm + w[1] * oof_rf + w[2] * oof_lgbm
        pred = (proba >= 0.5).astype(int)
        f1 = f1_score(y_true, pred, zero_division=0)
        return -f1  # gp_minimize meminimalkan -> kita minimalkan negatif F1

    res = gp_minimize(
        objective, space, n_calls=n_calls, n_initial_points=min(5, n_calls),
        random_state=RANDOM_STATE, verbose=False,
    )

    best_weights = {'w_svm': res.x[0], 'w_rf': res.x[1], 'w_lgbm': res.x[2]}
    best_f1_inner = -res.fun
    return best_weights, best_f1_inner


def _fit_final_and_predict(X_tr, y_tr, X_te, best_params, best_weights, resampling_method):
    svm_fixed  = SVC(probability=True, random_state=RANDOM_STATE, **best_params['svm'])
    rf_fixed   = RandomForestClassifier(random_state=RANDOM_STATE, n_jobs=1, **best_params['rf'])
    lgbm_fixed = lgb.LGBMClassifier(random_state=RANDOM_STATE, verbose=-1, n_jobs=1, **best_params['lgbm'])

    voting_model = WeightedSoftVoting(
        svm=svm_fixed, rf=rf_fixed, lgbm=lgbm_fixed,
        w_svm=best_weights['w_svm'], w_rf=best_weights['w_rf'], w_lgbm=best_weights['w_lgbm'],
    )
    pipe = _make_pipe(voting_model, resampling_method)
    pipe.fit(X_tr, y_tr)

    y_pred  = pipe.predict(X_te)
    y_proba = pipe.predict_proba(X_te)[:, 1]
    return y_pred, y_proba


def run_nested_cv_soft_voting(X, y, dataset_name='', resampling_method='none',
                              n_bayes_iter_params=20, n_bayes_iter_weights=15):
    X = X.reset_index(drop=True)
    y = pd.Series(np.asarray(y)).reset_index(drop=True)

    outer_cv = StratifiedKFold(n_splits=N_OUTER_FOLDS, shuffle=True, random_state=RANDOM_STATE)
    inner_cv = StratifiedKFold(n_splits=N_INNER_FOLDS, shuffle=True, random_state=RANDOM_STATE)

    accs, precs, recs, f1s, aucs = [], [], [], [], []
    fold_info = []

    print(f'\n  Nested 5-Fold CV — Soft Voting [Bayesian Optimization] [{dataset_name}] | {get_resampling_label(resampling_method)}')

    for fold_idx, (tr_idx, te_idx) in enumerate(outer_cv.split(X, y), start=1):
        X_tr, X_te = X.iloc[tr_idx], X.iloc[te_idx]
        y_tr, y_te = y.iloc[tr_idx], y.iloc[te_idx]

        best_params = get_best_params_for_voting(
            X_tr, y_tr, dataset_name=f'{dataset_name} | fold {fold_idx}',
            resampling_method=resampling_method, n_bayes_iter=n_bayes_iter_params,
        )

        oof_svm, oof_rf, oof_lgbm, y_oof = _get_oof_base_proba(
            X_tr, y_tr, best_params, resampling_method, inner_cv,
        )

        best_weights, best_f1_inner = _search_best_weights(
            oof_svm, oof_rf, oof_lgbm, y_oof, n_calls=n_bayes_iter_weights,
        )

        y_pred, y_proba = _fit_final_and_predict(
            X_tr, y_tr, X_te, best_params, best_weights, resampling_method,
        )

        acc  = accuracy_score(y_te, y_pred)
        prec = precision_score(y_te, y_pred, zero_division=0)
        rec  = recall_score(y_te, y_pred, zero_division=0)
        f1v  = f1_score(y_te, y_pred, zero_division=0)
        try:
            auc = roc_auc_score(y_te, y_proba)
        except ValueError:
            auc = np.nan

        accs.append(acc); precs.append(prec); recs.append(rec)
        f1s.append(f1v); aucs.append(auc)
        fold_info.append({'base_params': best_params, 'weights': best_weights,
                          'f1_inner_oof': best_f1_inner})

        print(f'    Fold {fold_idx}: Acc={acc*100:.2f}% Prec={prec*100:.2f}% '
              f'Rec={rec*100:.2f}% F1={f1v*100:.2f}% AUC={auc*100:.2f}%  '
              f'| weights={ {k: round(v,3) for k,v in best_weights.items()} }')

    acc  = np.array(accs); prec = np.array(precs); rec = np.array(recs)
    f1v  = np.array(f1s);  auc  = np.array(aucs)

    label = f'Soft Voting | {get_resampling_label(resampling_method)}'
    print(f'\n  {label} — mean across 5 folds')
    print(f'  {"Soft Voting Ensemble":<22}'
          f' {acc.mean()*100:>7.2f}%'
          f' ±{acc.std()*100:.2f}'
          f' {prec.mean()*100:>7.2f}%'
          f' {rec.mean()*100:>7.2f}%'
          f' {f1v.mean()*100:>7.2f}%'
          f' {auc.mean()*100:>7.2f}%')

    return {'acc': acc, 'prec': prec, 'rec': rec, 'f1': f1v, 'auc': auc,
            'fold_info': fold_info}

print('Soft Voting Ensemble functions initialized.')
# Out:
# Soft Voting Ensemble functions initialized.

# %% [markdown]
# ## 2.3 Dataset Evaluation Pipeline

# %%
# CELL 7 — Dataset Evaluation Pipeline

def evaluate_dataset(df, target_col, dataset_name,
                     binarize=True,
                     compare_resampling=False):
    print('\n' + '=' * 72)
    print(f'  DATASET: {dataset_name}')
    print('=' * 72)

    df = df.dropna(subset=[target_col]).copy()
    if binarize:
        df[target_col] = (pd.to_numeric(df[target_col], errors='coerce') > 0).astype(int)

    X_all = df.drop(columns=[target_col])
    y = df[target_col].astype(int)

    counter = Counter(y)
    majority = max(counter.values())
    minority = min(counter.values())
    imbalance_ratio = majority / minority
    use_smote = (imbalance_ratio > 2.0) or (dataset_name in IMBALANCED_DATASETS)

    print(f'  Records          : {len(df)}')
    print(f'  Initial features : {X_all.shape[1]}')
    print(f'  Class distribution: {dict(counter)}')
    print(f'  Imbalance ratio   : {imbalance_ratio:.2f}:1 | Initial SMOTE: {"Yes" if use_smote else "No"}')

    X_sel = X_all.copy()
    selected = X_all.columns.tolist()

    methods_to_run = RESAMPLING_METHODS if compare_resampling else [
        'smote' if use_smote else 'none'
    ]

    experiments = {}

    for resampling_method in methods_to_run:
        resampling_label = get_resampling_label(resampling_method)

        print('\n' + '─' * 72)
        print(f'  RESAMPLING METHOD: {resampling_label}')
        print('─' * 72)

        base_res = run_nested_cv_baseline(
            X_sel,
            y,
            dataset_name=dataset_name,
            resampling_method=resampling_method,
        )

        sv_res = run_nested_cv_soft_voting(
            X_sel,
            y,
            dataset_name=dataset_name,
            resampling_method=resampling_method,
        )
        base_res['Soft Voting Ensemble'] = sv_res

        experiments[resampling_label] = {
            'resampling_method': resampling_method,
            'results': base_res,
        }

    primary_method = 'smote' if use_smote else 'none'
    primary_label = get_resampling_label(primary_method)
    primary_experiment = experiments[primary_label]

    return {
        'dataset': dataset_name,
        'n_records': len(df),
        'n_features_total': X_all.shape[1],
        'n_features_selected': X_all.shape[1],
        'selected_features': selected,
        'class_dist': dict(counter),
        'imbalance_ratio': imbalance_ratio,
        'use_smote': use_smote,
        'results': primary_experiment['results'],
        'experiments': experiments,
    }

print('Evaluation pipeline initialized.')
# Out:
# Evaluation pipeline initialized.

# %% [markdown]
# # 3. Resampling Experiments

# %% [markdown]
# ## 3.1 Long Beach VA

# %%
# CELL 10 — Long Beach VA

url_va = ('https://archive.ics.uci.edu/ml/machine-learning-databases/'
          'heart-disease/processed.va.data')

cols = ['age','sex','cp','trestbps','chol','fbs','restecg',
        'thalach','exang','oldpeak','slope','ca','thal','target']

df_va = pd.read_csv(url_va, names=cols, na_values='?')
for c in cols:
    df_va[c] = pd.to_numeric(df_va[c], errors='coerce')

miss_rate = df_va.isnull().mean()
drop_cols = miss_rate[miss_rate > 0.9].index.tolist()
if drop_cols:
    print(f'Columns removed (>90% missing values): {drop_cols}')
    df_va = df_va.drop(columns=drop_cols)

summary_va = evaluate_dataset(
    df_va, 'target', 'Long Beach VA',
    compare_resampling=True
)
# Out:
# Columns removed (>90% missing values): ['ca']
#
# ========================================================================
#   DATASET: Long Beach VA
# ========================================================================
#   Records       : 200
#   Initial features   : 12
#   Class distribution: {1: 149, 0: 51}
#   Imbalance ratio    : 2.92:1: SMOTE awal: ✓ YA
#
# ────────────────────────────────────────────────────────────────────────
#   EKSPERIMEN RESAMPLING: No Resampling
# ────────────────────────────────────────────────────────────────────────
#
#   Nested 5-Fold CV — Baseline [Bayesian Optimization] [Long Beach VA] | No Resampling
#   Model                       Acc     ±     Prec      Rec       F1      AUC
#   ────────────────────────────────────────────────────────────────────────
#   SVM                      75.50% ±2.45   75.29%  100.00%   85.89%   69.87%
#   Naive Bayes              74.00% ±6.04   79.21%   88.55%   83.50%   70.99%
#   Random Forest            74.50% ±1.00   75.03%   98.67%   85.21%   69.47%
#   J48 (DecTree)            75.00% ±2.74   77.40%   93.95%   84.85%   56.59%
#   Logistic Regression      74.50% ±1.00   74.76%   99.33%   85.30%   70.04%
#   XGBoost                  74.50% ±1.00   74.76%   99.33%   85.30%   67.38%
#   LightGBM                 75.00% ±0.00   74.87%  100.00%   85.63%   70.37%
#   KNN                      78.00% ±2.92   79.05%   95.95%   86.66%   71.23%
#
#   Nested 5-Fold CV — Soft Voting [Bayesian Optimization] [Long Beach VA] | No Resampling
#
#   Bayesian optimization for Soft Voting base learners [Long Beach VA | fold 1]
#     svm   : {'C': 0.01, 'kernel': 'rbf'}  (F1 inner CV = 85.30%)
#     rf    : {'max_depth': 3, 'n_estimators': 254}  (F1 inner CV = 85.82%)
#     lgbm  : {'learning_rate': 0.01, 'n_estimators': 50, 'num_leaves': 7}  (F1 inner CV = 85.30%)
#     Fold 1: Acc=75.00% Prec=76.32% Rec=96.67% F1=85.29% AUC=71.00%  | bobot={'w_svm': 0.1, 'w_rf': 2.014, 'w_lgbm': 0.1}
#
#   Bayesian optimization for Soft Voting base learners [Long Beach VA | fold 2]
#     svm   : {'C': 0.010340016434251914, 'kernel': 'linear'}  (F1 inner CV = 85.30%)
#     rf    : {'max_depth': 3, 'n_estimators': 138}  (F1 inner CV = 85.39%)
#     lgbm  : {'learning_rate': 0.01, 'n_estimators': 50, 'num_leaves': 7}  (F1 inner CV = 85.30%)
#     Fold 2: Acc=75.00% Prec=75.00% Rec=100.00% F1=85.71% AUC=65.00%  | bobot={'w_svm': 2.41, 'w_rf': 0.632, 'w_lgbm': 2.361}
#
#   Bayesian optimization for Soft Voting base learners [Long Beach VA | fold 3]
#     svm   : {'C': 0.010340016434251914, 'kernel': 'linear'}  (F1 inner CV = 85.30%)
#     rf    : {'max_depth': 4, 'n_estimators': 211}  (F1 inner CV = 86.45%)
#     lgbm  : {'learning_rate': 0.010426716333775675, 'n_estimators': 50, 'num_leaves': 10}  (F1 inner CV = 85.30%)
#     Fold 3: Acc=75.00% Prec=75.00% Rec=100.00% F1=85.71% AUC=69.33%  | bobot={'w_svm': 0.1, 'w_rf': 3.0, 'w_lgbm': 0.1}
#
#   Bayesian optimization for Soft Voting base learners [Long Beach VA | fold 4]
#     svm   : {'C': 0.5948999309813165, 'kernel': 'rbf'}  (F1 inner CV = 85.50%)
#     rf    : {'max_depth': 3, 'n_estimators': 254}  (F1 inner CV = 85.08%)
#     lgbm  : {'learning_rate': 0.01, 'n_estimators': 50, 'num_leaves': 7}  (F1 inner CV = 85.30%)
#     Fold 4: Acc=80.00% Prec=78.95% Rec=100.00% F1=88.24% AUC=72.00%  | bobot={'w_svm': 2.022, 'w_rf': 0.375, 'w_lgbm': 2.77}
#
#   Bayesian optimization for Soft Voting base learners [Long Beach VA | fold 5]
#     svm   : {'C': 0.010340016434251914, 'kernel': 'linear'}  (F1 inner CV = 85.71%)
#     rf    : {'max_depth': 3, 'n_estimators': 212}  (F1 inner CV = 84.88%)
#     lgbm  : {'learning_rate': 0.01, 'n_estimators': 213, 'num_leaves': 150}  (F1 inner CV = 86.20%)
#     Fold 5: Acc=72.50% Prec=72.50% Rec=100.00% F1=84.06% AUC=69.28%  | bobot={'w_svm': 2.41, 'w_rf': 0.632, 'w_lgbm': 2.361}
#
#   ═══ Soft Voting | No Resampling — mean across 5 folds ═══
#   Soft Voting Ensemble     75.50% ±2.45   75.55%   99.33%   85.80%   69.32%
#
# ────────────────────────────────────────────────────────────────────────
#   EKSPERIMEN RESAMPLING: SMOTE
# ────────────────────────────────────────────────────────────────────────
#
#   Nested 5-Fold CV — Baseline [Bayesian Optimization] [Long Beach VA] | SMOTE
#   Model                       Acc     ±     Prec      Rec       F1      AUC
#   ────────────────────────────────────────────────────────────────────────
#   SVM                      71.00% ±3.74   80.58%   80.53%   80.37%   67.46%
#   Naive Bayes              70.50% ±4.00   83.13%   75.86%   79.23%   67.38%
#   Random Forest            74.50% ±5.79   79.62%   88.60%   83.65%   67.14%
#   J48 (DecTree)            73.00% ±4.00   80.52%   84.57%   82.16%   61.70%
#   Logistic Regression      70.00% ±6.32   85.13%   72.48%   78.08%   67.85%
#   XGBoost                  73.00% ±1.87   80.18%   85.29%   82.47%   67.76%
#   LightGBM                 70.00% ±6.89   78.83%   81.93%   79.89%   62.64%
#   KNN                      67.50% ±4.18   83.15%   71.15%   76.46%   65.78%
#
#   Nested 5-Fold CV — Soft Voting [Bayesian Optimization] [Long Beach VA] | SMOTE
#
#   Bayesian optimization for Soft Voting base learners [Long Beach VA | fold 1]
#     svm   : {'C': 100.0, 'kernel': 'rbf'}  (F1 inner CV = 81.63%)
#     rf    : {'max_depth': 26, 'n_estimators': 271}  (F1 inner CV = 82.14%)
#     lgbm  : {'learning_rate': 0.045401641878176635, 'n_estimators': 463, 'num_leaves': 22}  (F1 inner CV = 80.17%)
#     Fold 1: Acc=82.50% Prec=82.86% Rec=96.67% F1=89.23% AUC=66.67%  | bobot={'w_svm': 0.1, 'w_rf': 2.786, 'w_lgbm': 0.1}
#
#   Bayesian optimization for Soft Voting base learners [Long Beach VA | fold 2]
#     svm   : {'C': 17.76576664980768, 'kernel': 'rbf'}  (F1 inner CV = 82.21%)
#     rf    : {'max_depth': 30, 'n_estimators': 53}  (F1 inner CV = 81.64%)
#     lgbm  : {'learning_rate': 0.29999999999999993, 'n_estimators': 53, 'num_leaves': 82}  (F1 inner CV = 81.31%)
#     Fold 2: Acc=75.00% Prec=79.41% Rec=90.00% F1=84.38% AUC=63.33%  | bobot={'w_svm': 1.432, 'w_rf': 1.068, 'w_lgbm': 0.514}
#
#   Bayesian optimization for Soft Voting base learners [Long Beach VA | fold 3]
#     svm   : {'C': 1.1356226192201788, 'kernel': 'rbf'}  (F1 inner CV = 79.90%)
#     rf    : {'max_depth': 14, 'n_estimators': 109}  (F1 inner CV = 83.52%)
#     lgbm  : {'learning_rate': 0.17255364529395611, 'n_estimators': 447, 'num_leaves': 50}  (F1 inner CV = 81.74%)
#     Fold 3: Acc=75.00% Prec=83.33% Rec=83.33% F1=83.33% AUC=74.33%  | bobot={'w_svm': 3.0, 'w_rf': 1.927, 'w_lgbm': 2.457}
#
#   Bayesian optimization for Soft Voting base learners [Long Beach VA | fold 4]
#     svm   : {'C': 0.01, 'kernel': 'rbf'}  (F1 inner CV = 81.20%)
#     rf    : {'max_depth': 3, 'n_estimators': 52}  (F1 inner CV = 80.88%)
#     lgbm  : {'learning_rate': 0.010862318475365472, 'n_estimators': 50, 'num_leaves': 134}  (F1 inner CV = 79.59%)
#     Fold 4: Acc=67.50% Prec=81.48% Rec=73.33% F1=77.19% AUC=66.33%  | bobot={'w_svm': 0.1, 'w_rf': 3.0, 'w_lgbm': 0.1}
#
#   Bayesian optimization for Soft Voting base learners [Long Beach VA | fold 5]
#     svm   : {'C': 0.7112577569630062, 'kernel': 'rbf'}  (F1 inner CV = 82.04%)
#     rf    : {'max_depth': 26, 'n_estimators': 271}  (F1 inner CV = 82.68%)
#     lgbm  : {'learning_rate': 0.024502898688425517, 'n_estimators': 212, 'num_leaves': 7}  (F1 inner CV = 83.59%)
#     Fold 5: Acc=72.50% Prec=76.47% Rec=89.66% F1=82.54% AUC=67.08%  | bobot={'w_svm': 0.868, 'w_rf': 0.664, 'w_lgbm': 2.983}
#
#   ═══ Soft Voting | SMOTE — mean across 5 folds ═══
#   Soft Voting Ensemble     74.50% ±4.85   80.71%   86.60%   83.33%   67.55%
#
#   ── SHAP Analysis [Long Beach VA] ──
#   Saved: shap_bar_Long_Beach_VA_smote.png
#   Saved: shap_beeswarm_Long_Beach_VA_smote.png
#
#   Top 10 fitur berdasarkan SHAP:
#  feature  mean_shap
#       cp   1.034622
#      age   0.777369
#     chol   0.657868
#      fbs   0.589293
#    exang   0.537767
#  oldpeak   0.432968
#  restecg   0.354567
#  thalach   0.286515
# trestbps   0.275607
#    slope   0.110360
#
# ────────────────────────────────────────────────────────────────────────
#   EKSPERIMEN RESAMPLING: Borderline-SMOTE
# ────────────────────────────────────────────────────────────────────────
#
#   Nested 5-Fold CV — Baseline [Bayesian Optimization] [Long Beach VA] | Borderline-SMOTE
#   Model                       Acc     ±     Prec      Rec       F1      AUC
#   ────────────────────────────────────────────────────────────────────────
#   SVM                      72.00% ±2.92   82.29%   79.82%   80.83%   68.79%
#   Naive Bayes              70.00% ±4.18   82.69%   75.79%   78.83%   69.08%
#   Random Forest            74.50% ±5.79   81.06%   85.86%   83.16%   68.76%
#   J48 (DecTree)            65.50% ±6.60   80.87%   71.17%   75.47%   60.81%
#   Logistic Regression      68.50% ±5.15   84.83%   70.41%   76.74%   69.96%
#   XGBoost                  71.50% ±3.39   79.46%   83.95%   81.28%   65.16%
#   LightGBM                 71.50% ±3.00   80.79%   81.22%   80.93%   68.29%
#   KNN                      65.00% ±4.18   82.11%   67.77%   74.24%   64.61%
#
#   Nested 5-Fold CV — Soft Voting [Bayesian Optimization] [Long Beach VA] | Borderline-SMOTE
#
#   Bayesian optimization for Soft Voting base learners [Long Beach VA | fold 1]
#     svm   : {'C': 0.7106379787688987, 'kernel': 'rbf'}  (F1 inner CV = 82.64%)
#     rf    : {'max_depth': 26, 'n_estimators': 271}  (F1 inner CV = 82.28%)
#     lgbm  : {'learning_rate': 0.13226985095195642, 'n_estimators': 500, 'num_leaves': 144}  (F1 inner CV = 81.57%)
#     Fold 1: Acc=80.00% Prec=82.35% Rec=93.33% F1=87.50% AUC=63.67%  | bobot={'w_svm': 2.65, 'w_rf': 1.891, 'w_lgbm': 1.499}
#
#   Bayesian optimization for Soft Voting base learners [Long Beach VA | fold 2]
#     svm   : {'C': 20.82678521028959, 'kernel': 'rbf'}  (F1 inner CV = 80.29%)
#     rf    : {'max_depth': 25, 'n_estimators': 160}  (F1 inner CV = 83.61%)
#     lgbm  : {'learning_rate': 0.010108091194359068, 'n_estimators': 54, 'num_leaves': 37}  (F1 inner CV = 79.17%)
#     Fold 2: Acc=72.50% Prec=78.79% Rec=86.67% F1=82.54% AUC=65.67%  | bobot={'w_svm': 2.237, 'w_rf': 2.93, 'w_lgbm': 2.065}
#
#   Bayesian optimization for Soft Voting base learners [Long Beach VA | fold 3]
#     svm   : {'C': 0.010340016434251914, 'kernel': 'linear'}  (F1 inner CV = 78.28%)
#     rf    : {'max_depth': 25, 'n_estimators': 160}  (F1 inner CV = 83.65%)
#     lgbm  : {'learning_rate': 0.29999999999999993, 'n_estimators': 500, 'num_leaves': 7}  (F1 inner CV = 82.61%)
#     Fold 3: Acc=70.00% Prec=82.14% Rec=76.67% F1=79.31% AUC=72.67%  | bobot={'w_svm': 0.501, 'w_rf': 0.1, 'w_lgbm': 3.0}
#
#   Bayesian optimization for Soft Voting base learners [Long Beach VA | fold 4]
#     svm   : {'C': 0.24959674243519547, 'kernel': 'rbf'}  (F1 inner CV = 81.01%)
#     rf    : {'max_depth': 4, 'n_estimators': 128}  (F1 inner CV = 81.08%)
#     lgbm  : {'learning_rate': 0.01, 'n_estimators': 414, 'num_leaves': 7}  (F1 inner CV = 78.13%)
#     Fold 4: Acc=72.50% Prec=85.19% Rec=76.67% F1=80.70% AUC=69.67%  | bobot={'w_svm': 2.096, 'w_rf': 2.51, 'w_lgbm': 0.1}
#
#   Bayesian optimization for Soft Voting base learners [Long Beach VA | fold 5]
#     svm   : {'C': 0.6363848861367152, 'kernel': 'rbf'}  (F1 inner CV = 82.95%)
#     rf    : {'max_depth': 7, 'n_estimators': 299}  (F1 inner CV = 84.42%)
#     lgbm  : {'learning_rate': 0.044216101232596935, 'n_estimators': 50, 'num_leaves': 86}  (F1 inner CV = 83.00%)
#     Fold 5: Acc=70.00% Prec=77.42% Rec=82.76% F1=80.00% AUC=73.35%  | bobot={'w_svm': 0.497, 'w_rf': 2.969, 'w_lgbm': 0.1}
#
#   ═══ Soft Voting | Borderline-SMOTE — mean across 5 folds ═══
#   Soft Voting Ensemble     73.00% ±3.67   81.18%   83.22%   82.01%   69.00%
#
# ────────────────────────────────────────────────────────────────────────
#   EKSPERIMEN RESAMPLING: SMOTE-Tomek
# ────────────────────────────────────────────────────────────────────────
#
#   Nested 5-Fold CV — Baseline [Bayesian Optimization] [Long Beach VA] | SMOTE-Tomek
#   Model                       Acc     ±     Prec      Rec       F1      AUC
#   ────────────────────────────────────────────────────────────────────────
#   SVM                      71.00% ±4.90   80.97%   79.86%   80.32%   70.14%
#   Naive Bayes              70.50% ±2.92   83.85%   75.84%   79.09%   70.80%
#   Random Forest            74.50% ±5.10   80.75%   86.55%   83.33%   68.01%
#   J48 (DecTree)            68.50% ±6.82   81.71%   74.46%   77.68%   65.21%
#   Logistic Regression      70.50% ±5.79   85.97%   72.46%   78.35%   69.49%
#   XGBoost                  73.50% ±4.64   80.63%   85.26%   82.58%   63.76%
#   LightGBM                 71.00% ±4.90   79.80%   81.91%   80.78%   69.91%
#   KNN                      64.00% ±4.64   82.35%   65.79%   72.98%   68.27%
#
#   Nested 5-Fold CV — Soft Voting [Bayesian Optimization] [Long Beach VA] | SMOTE-Tomek
#
#   Bayesian optimization for Soft Voting base learners [Long Beach VA | fold 1]
#     svm   : {'C': 68.2519664747372, 'kernel': 'rbf'}  (F1 inner CV = 82.18%)
#     rf    : {'max_depth': 23, 'n_estimators': 285}  (F1 inner CV = 82.09%)
#     lgbm  : {'learning_rate': 0.01, 'n_estimators': 472, 'num_leaves': 7}  (F1 inner CV = 77.10%)
#     Fold 1: Acc=75.00% Prec=81.25% Rec=86.67% F1=83.87% AUC=73.67%  | bobot={'w_svm': 0.1, 'w_rf': 0.1, 'w_lgbm': 0.1}
#
#   Bayesian optimization for Soft Voting base learners [Long Beach VA | fold 2]
#     svm   : {'C': 100.0, 'kernel': 'rbf'}  (F1 inner CV = 81.84%)
#     rf    : {'max_depth': 14, 'n_estimators': 232}  (F1 inner CV = 81.11%)
#     lgbm  : {'learning_rate': 0.1584920130931114, 'n_estimators': 127, 'num_leaves': 93}  (F1 inner CV = 81.42%)
#     Fold 2: Acc=72.50% Prec=77.14% Rec=90.00% F1=83.08% AUC=63.67%  | bobot={'w_svm': 2.431, 'w_rf': 2.814, 'w_lgbm': 0.455}
#
#   Bayesian optimization for Soft Voting base learners [Long Beach VA | fold 3]
#     svm   : {'C': 0.7185801117178471, 'kernel': 'rbf'}  (F1 inner CV = 79.45%)
#     rf    : {'max_depth': 11, 'n_estimators': 51}  (F1 inner CV = 82.56%)
#     lgbm  : {'learning_rate': 0.17255364529395611, 'n_estimators': 447, 'num_leaves': 50}  (F1 inner CV = 80.93%)
#     Fold 3: Acc=80.00% Prec=82.35% Rec=93.33% F1=87.50% AUC=78.00%  | bobot={'w_svm': 1.432, 'w_rf': 1.068, 'w_lgbm': 0.514}
#
#   Bayesian optimization for Soft Voting base learners [Long Beach VA | fold 4]
#     svm   : {'C': 0.01287697805315783, 'kernel': 'rbf'}  (F1 inner CV = 81.45%)
#     rf    : {'max_depth': 8, 'n_estimators': 185}  (F1 inner CV = 82.39%)
#     lgbm  : {'learning_rate': 0.06363785063702598, 'n_estimators': 50, 'num_leaves': 111}  (F1 inner CV = 80.34%)
#     Fold 4: Acc=70.00% Prec=84.62% Rec=73.33% F1=78.57% AUC=73.00%  | bobot={'w_svm': 1.831, 'w_rf': 1.393, 'w_lgbm': 0.39}
#
#   Bayesian optimization for Soft Voting base learners [Long Beach VA | fold 5]
#     svm   : {'C': 0.829776243218943, 'kernel': 'rbf'}  (F1 inner CV = 82.30%)
#     rf    : {'max_depth': 25, 'n_estimators': 160}  (F1 inner CV = 83.66%)
#     lgbm  : {'learning_rate': 0.010031193410587504, 'n_estimators': 343, 'num_leaves': 9}  (F1 inner CV = 82.23%)
#     Fold 5: Acc=70.00% Prec=75.76% Rec=86.21% F1=80.65% AUC=69.91%  | bobot={'w_svm': 0.461, 'w_rf': 2.485, 'w_lgbm': 2.756}
#
#   ═══ Soft Voting | SMOTE-Tomek — mean across 5 folds ═══
#   Soft Voting Ensemble     73.50% ±3.74   80.22%   85.91%   82.73%   71.65%

# %% [markdown]
# ## 3.2 Heart Failure Clinical Records

# %%
# CELL 12 — Heart Failure Clinical Records

url_hf = ('https://archive.ics.uci.edu/ml/machine-learning-databases/'
          '00519/heart_failure_clinical_records_dataset.csv')

df_hf = pd.read_csv(url_hf)
print('Dataset shape:', df_hf.shape)
print(f'DEATH_EVENT distribution: {Counter(df_hf["DEATH_EVENT"])}')

summary_hf = evaluate_dataset(
    df_hf, 'DEATH_EVENT', 'Heart Failure Clinical',
    binarize=False,
    compare_resampling=True
)
# Out:
# Dataset shape: (299, 13)
# DEATH_EVENT distribution: Counter({0: 203, 1: 96})
#
# ========================================================================
#   DATASET: Heart Failure Clinical
# ========================================================================
#   Records       : 299
#   Initial features   : 12
#   Class distribution: {1: 96, 0: 203}
#   Imbalance ratio    : 2.11:1: SMOTE awal: ✓ YA
#
# ────────────────────────────────────────────────────────────────────────
#   EKSPERIMEN RESAMPLING: No Resampling
# ────────────────────────────────────────────────────────────────────────
#
#   Nested 5-Fold CV — Baseline [Bayesian Optimization] [Heart Failure Clinical] | No Resampling
#   Model                       Acc     ±     Prec      Rec       F1      AUC
#   ────────────────────────────────────────────────────────────────────────
#   SVM                      82.26% ±2.61   78.13%   62.42%   69.22%   86.64%
#   Naive Bayes              77.59% ±3.29   74.43%   46.89%   57.45%   85.15%
#   Random Forest            83.26% ±4.56   76.64%   68.68%   72.13%   89.82%
#   J48 (DecTree)            80.94% ±2.48   73.31%   65.42%   68.05%   85.44%
#   Logistic Regression      83.59% ±4.65   78.61%   67.74%   72.55%   87.54%
#   XGBoost                  82.94% ±4.13   75.76%   68.74%   71.86%   90.31%
#   LightGBM                 84.94% ±2.40   80.83%   69.74%   74.61%   90.69%
#   KNN                      70.90% ±3.13   58.80%   32.21%   40.98%   74.44%
#
#   Nested 5-Fold CV — Soft Voting [Bayesian Optimization] [Heart Failure Clinical] | No Resampling
#
#   Bayesian optimization for Soft Voting base learners [Heart Failure Clinical | fold 1]
#     svm   : {'C': 1.491462267977867, 'kernel': 'linear'}  (F1 inner CV = 70.71%)
#     rf    : {'max_depth': 26, 'n_estimators': 271}  (F1 inner CV = 75.01%)
#     lgbm  : {'learning_rate': 0.01, 'n_estimators': 469, 'num_leaves': 7}  (F1 inner CV = 71.62%)
#     Fold 1: Acc=86.67% Prec=83.33% Rec=75.00% F1=78.95% AUC=91.38%  | bobot={'w_svm': 2.062, 'w_rf': 1.98, 'w_lgbm': 2.021}
#
#   Bayesian optimization for Soft Voting base learners [Heart Failure Clinical | fold 2]
#     svm   : {'C': 66.36085077612337, 'kernel': 'linear'}  (F1 inner CV = 71.18%)
#     rf    : {'max_depth': 25, 'n_estimators': 93}  (F1 inner CV = 75.87%)
#     lgbm  : {'learning_rate': 0.010124239352823897, 'n_estimators': 418, 'num_leaves': 113}  (F1 inner CV = 74.12%)
#     Fold 2: Acc=86.67% Prec=78.95% Rec=78.95% F1=78.95% AUC=88.32%  | bobot={'w_svm': 1.198, 'w_rf': 1.926, 'w_lgbm': 0.442}
#
#   Bayesian optimization for Soft Voting base learners [Heart Failure Clinical | fold 3]
#     svm   : {'C': 0.906626504904989, 'kernel': 'rbf'}  (F1 inner CV = 66.86%)
#     rf    : {'max_depth': 25, 'n_estimators': 93}  (F1 inner CV = 73.16%)
#     lgbm  : {'learning_rate': 0.010124239352823897, 'n_estimators': 418, 'num_leaves': 113}  (F1 inner CV = 73.66%)
#     Fold 3: Acc=88.33% Prec=83.33% Rec=78.95% F1=81.08% AUC=92.43%  | bobot={'w_svm': 1.211, 'w_rf': 0.1, 'w_lgbm': 3.0}
#
#   Bayesian optimization for Soft Voting base learners [Heart Failure Clinical | fold 4]
#     svm   : {'C': 22.364202820542708, 'kernel': 'linear'}  (F1 inner CV = 71.31%)
#     rf    : {'max_depth': 3, 'n_estimators': 117}  (F1 inner CV = 73.61%)
#     lgbm  : {'learning_rate': 0.045401641878176635, 'n_estimators': 463, 'num_leaves': 22}  (F1 inner CV = 73.64%)
#     Fold 4: Acc=81.67% Prec=78.57% Rec=57.89% F1=66.67% AUC=91.53%  | bobot={'w_svm': 0.1, 'w_rf': 0.1, 'w_lgbm': 1.455}
#
#   Bayesian optimization for Soft Voting base learners [Heart Failure Clinical | fold 5]
#     svm   : {'C': 1.491462267977867, 'kernel': 'linear'}  (F1 inner CV = 74.98%)
#     rf    : {'max_depth': 25, 'n_estimators': 152}  (F1 inner CV = 79.55%)
#     lgbm  : {'learning_rate': 0.01, 'n_estimators': 170, 'num_leaves': 15}  (F1 inner CV = 76.25%)
#     Fold 5: Acc=79.66% Prec=73.33% Rec=57.89% F1=64.71% AUC=90.53%  | bobot={'w_svm': 2.41, 'w_rf': 0.632, 'w_lgbm': 2.361}
#
#   ═══ Soft Voting | No Resampling — mean across 5 folds ═══
#   Soft Voting Ensemble     84.60% ±3.33   79.50%   69.74%   74.07%   90.83%
#
# ────────────────────────────────────────────────────────────────────────
#   EKSPERIMEN RESAMPLING: SMOTE
# ────────────────────────────────────────────────────────────────────────
#
#   Nested 5-Fold CV — Baseline [Bayesian Optimization] [Heart Failure Clinical] | SMOTE
#   Model                       Acc     ±     Prec      Rec       F1      AUC
#   ────────────────────────────────────────────────────────────────────────
#   SVM                      78.60% ±2.60   65.05%   76.05%   69.58%   87.34%
#   Naive Bayes              78.93% ±3.76   69.69%   63.63%   65.86%   84.18%
#   Random Forest            83.94% ±2.33   75.72%   73.89%   74.58%   90.70%
#   J48 (DecTree)            81.26% ±2.54   69.42%   75.95%   72.12%   82.61%
#   Logistic Regression      79.28% ±3.02   65.83%   77.11%   70.58%   87.59%
#   XGBoost                  81.92% ±4.62   70.45%   74.84%   72.30%   89.29%
#   LightGBM                 82.94% ±1.99   72.57%   76.89%   73.91%   90.09%
#   KNN                      70.90% ±5.56   53.66%   66.58%   59.35%   77.89%
#
#   Nested 5-Fold CV — Soft Voting [Bayesian Optimization] [Heart Failure Clinical] | SMOTE
#
#   Bayesian optimization for Soft Voting base learners [Heart Failure Clinical | fold 1]
#     svm   : {'C': 0.018236628723898446, 'kernel': 'linear'}  (F1 inner CV = 73.31%)
#     rf    : {'max_depth': 26, 'n_estimators': 105}  (F1 inner CV = 77.35%)
#     lgbm  : {'learning_rate': 0.01, 'n_estimators': 50, 'num_leaves': 95}  (F1 inner CV = 73.43%)
#     Fold 1: Acc=80.00% Prec=66.67% Rec=80.00% F1=72.73% AUC=88.75%  | bobot={'w_svm': 1.857, 'w_rf': 0.1, 'w_lgbm': 2.654}
#
#   Bayesian optimization for Soft Voting base learners [Heart Failure Clinical | fold 2]
#     svm   : {'C': 0.010340016434251914, 'kernel': 'linear'}  (F1 inner CV = 69.18%)
#     rf    : {'max_depth': 25, 'n_estimators': 107}  (F1 inner CV = 76.26%)
#     lgbm  : {'learning_rate': 0.040909621289369986, 'n_estimators': 485, 'num_leaves': 38}  (F1 inner CV = 77.26%)
#     Fold 2: Acc=85.00% Prec=75.00% Rec=78.95% F1=76.92% AUC=86.26%  | bobot={'w_svm': 1.379, 'w_rf': 1.138, 'w_lgbm': 0.478}
#
#   Bayesian optimization for Soft Voting base learners [Heart Failure Clinical | fold 3]
#     svm   : {'C': 0.0100094951774709, 'kernel': 'linear'}  (F1 inner CV = 69.60%)
#     rf    : {'max_depth': 3, 'n_estimators': 88}  (F1 inner CV = 76.67%)
#     lgbm  : {'learning_rate': 0.01034961794508543, 'n_estimators': 197, 'num_leaves': 7}  (F1 inner CV = 76.85%)
#     Fold 3: Acc=81.67% Prec=68.18% Rec=78.95% F1=73.17% AUC=92.81%  | bobot={'w_svm': 0.472, 'w_rf': 0.1, 'w_lgbm': 3.0}
#
#   Bayesian optimization for Soft Voting base learners [Heart Failure Clinical | fold 4]
#     svm   : {'C': 0.010340016434251914, 'kernel': 'linear'}  (F1 inner CV = 68.63%)
#     rf    : {'max_depth': 30, 'n_estimators': 71}  (F1 inner CV = 75.50%)
#     lgbm  : {'learning_rate': 0.026909584840079243, 'n_estimators': 242, 'num_leaves': 31}  (F1 inner CV = 74.83%)
#     Fold 4: Acc=83.33% Prec=73.68% Rec=73.68% F1=73.68% AUC=88.83%  | bobot={'w_svm': 0.1, 'w_rf': 0.519, 'w_lgbm': 1.766}
#
#   Bayesian optimization for Soft Voting base learners [Heart Failure Clinical | fold 5]
#     svm   : {'C': 0.123700473392915, 'kernel': 'linear'}  (F1 inner CV = 73.05%)
#     rf    : {'max_depth': 3, 'n_estimators': 254}  (F1 inner CV = 79.41%)
#     lgbm  : {'learning_rate': 0.06348516039427839, 'n_estimators': 464, 'num_leaves': 78}  (F1 inner CV = 78.61%)
#     Fold 5: Acc=81.36% Prec=75.00% Rec=63.16% F1=68.57% AUC=88.68%  | bobot={'w_svm': 3.0, 'w_rf': 0.313, 'w_lgbm': 2.176}
#
#   ═══ Soft Voting | SMOTE — mean across 5 folds ═══
#   Soft Voting Ensemble     82.27% ±1.73   71.71%   74.95%   73.02%   89.07%
#
#   ── SHAP Analysis [Heart Failure Clinical] ──
#   Saved: shap_bar_Heart_Failure_Clinical_smote.png
#   Saved: shap_beeswarm_Heart_Failure_Clinical_smote.png
#
#   Top 10 fitur berdasarkan SHAP:
#                  feature  mean_shap
#                     time   2.936081
#        ejection_fraction   1.440113
#         serum_creatinine   1.222491
# creatinine_phosphokinase   0.677391
#             serum_sodium   0.674533
#                      age   0.481705
#                platelets   0.456479
#                      sex   0.269926
#                  anaemia   0.127001
#                 diabetes   0.085162
#
# ────────────────────────────────────────────────────────────────────────
#   EKSPERIMEN RESAMPLING: Borderline-SMOTE
# ────────────────────────────────────────────────────────────────────────
#
#   Nested 5-Fold CV — Baseline [Bayesian Optimization] [Heart Failure Clinical] | Borderline-SMOTE
#   Model                       Acc     ±     Prec      Rec       F1      AUC
#   ────────────────────────────────────────────────────────────────────────
#   SVM                      79.61% ±2.80   66.21%   78.11%   71.18%   87.68%
#   Naive Bayes              79.27% ±4.29   69.96%   67.74%   68.04%   83.32%
#   Random Forest            82.93% ±2.59   72.22%   76.00%   73.94%   90.19%
#   J48 (DecTree)            78.94% ±3.52   64.87%   76.95%   70.01%   82.43%
#   Logistic Regression      79.61% ±2.59   66.14%   78.11%   71.16%   86.95%
#   XGBoost                  82.27% ±2.28   71.46%   74.95%   72.98%   88.33%
#   LightGBM                 83.27% ±2.40   72.65%   76.95%   74.42%   90.46%
#   KNN                      69.57% ±4.61   52.37%   64.53%   57.70%   77.99%
#
#   Nested 5-Fold CV — Soft Voting [Bayesian Optimization] [Heart Failure Clinical] | Borderline-SMOTE
#
#   Bayesian optimization for Soft Voting base learners [Heart Failure Clinical | fold 1]
#     svm   : {'C': 0.09207044360331094, 'kernel': 'linear'}  (F1 inner CV = 73.79%)
#     rf    : {'max_depth': 4, 'n_estimators': 133}  (F1 inner CV = 77.56%)
#     lgbm  : {'learning_rate': 0.047103767429783, 'n_estimators': 66, 'num_leaves': 7}  (F1 inner CV = 74.68%)
#     Fold 1: Acc=80.00% Prec=66.67% Rec=80.00% F1=72.73% AUC=91.62%  | bobot={'w_svm': 0.103, 'w_rf': 2.011, 'w_lgbm': 0.35}
#
#   Bayesian optimization for Soft Voting base learners [Heart Failure Clinical | fold 2]
#     svm   : {'C': 0.010340016434251914, 'kernel': 'linear'}  (F1 inner CV = 72.84%)
#     rf    : {'max_depth': 26, 'n_estimators': 271}  (F1 inner CV = 76.78%)
#     lgbm  : {'learning_rate': 0.08018054537456736, 'n_estimators': 105, 'num_leaves': 7}  (F1 inner CV = 75.74%)
#     Fold 2: Acc=85.00% Prec=75.00% Rec=78.95% F1=76.92% AUC=89.47%  | bobot={'w_svm': 1.714, 'w_rf': 3.0, 'w_lgbm': 0.87}
#
#   Bayesian optimization for Soft Voting base learners [Heart Failure Clinical | fold 3]
#     svm   : {'C': 0.1124276325235605, 'kernel': 'linear'}  (F1 inner CV = 70.67%)
#     rf    : {'max_depth': 4, 'n_estimators': 114}  (F1 inner CV = 77.10%)
#     lgbm  : {'learning_rate': 0.06618574312817609, 'n_estimators': 499, 'num_leaves': 86}  (F1 inner CV = 74.82%)
#     Fold 3: Acc=86.67% Prec=73.91% Rec=89.47% F1=80.95% AUC=94.48%  | bobot={'w_svm': 3.0, 'w_rf': 2.133, 'w_lgbm': 0.807}
#
#   Bayesian optimization for Soft Voting base learners [Heart Failure Clinical | fold 4]
#     svm   : {'C': 0.010340016434251914, 'kernel': 'linear'}  (F1 inner CV = 69.64%)
#     rf    : {'max_depth': 3, 'n_estimators': 106}  (F1 inner CV = 75.73%)
#     lgbm  : {'learning_rate': 0.018075774390001142, 'n_estimators': 243, 'num_leaves': 149}  (F1 inner CV = 75.86%)
#     Fold 4: Acc=81.67% Prec=72.22% Rec=68.42% F1=70.27% AUC=90.50%  | bobot={'w_svm': 0.1, 'w_rf': 0.1, 'w_lgbm': 2.619}
#
#   Bayesian optimization for Soft Voting base learners [Heart Failure Clinical | fold 5]
#     svm   : {'C': 66.36085077612337, 'kernel': 'linear'}  (F1 inner CV = 71.26%)
#     rf    : {'max_depth': 24, 'n_estimators': 136}  (F1 inner CV = 79.79%)
#     lgbm  : {'learning_rate': 0.01, 'n_estimators': 463, 'num_leaves': 46}  (F1 inner CV = 78.02%)
#     Fold 5: Acc=83.05% Prec=73.68% Rec=73.68% F1=73.68% AUC=89.87%  | bobot={'w_svm': 0.202, 'w_rf': 1.623, 'w_lgbm': 3.0}
#
#   ═══ Soft Voting | Borderline-SMOTE — mean across 5 folds ═══
#   Soft Voting Ensemble     83.28% ±2.36   72.30%   78.11%   74.91%   91.19%
#
# ────────────────────────────────────────────────────────────────────────
#   EKSPERIMEN RESAMPLING: SMOTE-Tomek
# ────────────────────────────────────────────────────────────────────────
#
#   Nested 5-Fold CV — Baseline [Bayesian Optimization] [Heart Failure Clinical] | SMOTE-Tomek
#   Model                       Acc     ±     Prec      Rec       F1      AUC
#   ────────────────────────────────────────────────────────────────────────
#   SVM                      78.25% ±4.66   65.81%   72.95%   68.50%   86.25%
#   Naive Bayes              78.25% ±4.50   69.69%   61.47%   64.58%   83.28%
#   Random Forest            86.28% ±2.52   77.85%   80.16%   78.71%   90.59%
#   J48 (DecTree)            79.93% ±1.83   65.04%   83.21%   72.58%   81.78%
#   Logistic Regression      79.60% ±1.88   65.48%   79.16%   71.34%   86.20%
#   XGBoost                  83.60% ±3.78   73.81%   75.89%   74.49%   89.89%
#   LightGBM                 82.61% ±1.68   73.54%   72.95%   72.92%   89.07%
#   KNN                      71.90% ±4.77   55.59%   69.89%   61.66%   78.39%
#
#   Nested 5-Fold CV — Soft Voting [Bayesian Optimization] [Heart Failure Clinical] | SMOTE-Tomek
#
#   Bayesian optimization for Soft Voting base learners [Heart Failure Clinical | fold 1]
#     svm   : {'C': 0.056105694623114065, 'kernel': 'linear'}  (F1 inner CV = 71.36%)
#     rf    : {'max_depth': 14, 'n_estimators': 232}  (F1 inner CV = 74.57%)
#     lgbm  : {'learning_rate': 0.06898848985771962, 'n_estimators': 483, 'num_leaves': 110}  (F1 inner CV = 73.20%)
#     Fold 1: Acc=85.00% Prec=76.19% Rec=80.00% F1=78.05% AUC=90.25%  | bobot={'w_svm': 2.067, 'w_rf': 2.753, 'w_lgbm': 1.06}
#
#   Bayesian optimization for Soft Voting base learners [Heart Failure Clinical | fold 2]
#     svm   : {'C': 0.1137723650215609, 'kernel': 'linear'}  (F1 inner CV = 67.38%)
#     rf    : {'max_depth': 3, 'n_estimators': 62}  (F1 inner CV = 77.84%)
#     lgbm  : {'learning_rate': 0.01, 'n_estimators': 293, 'num_leaves': 23}  (F1 inner CV = 79.71%)
#     Fold 2: Acc=83.33% Prec=71.43% Rec=78.95% F1=75.00% AUC=87.55%  | bobot={'w_svm': 0.135, 'w_rf': 0.345, 'w_lgbm': 0.526}
#
#   Bayesian optimization for Soft Voting base learners [Heart Failure Clinical | fold 3]
#     svm   : {'C': 0.010340016434251914, 'kernel': 'linear'}  (F1 inner CV = 72.13%)
#     rf    : {'max_depth': 3, 'n_estimators': 50}  (F1 inner CV = 77.40%)
#     lgbm  : {'learning_rate': 0.014703928148722801, 'n_estimators': 157, 'num_leaves': 48}  (F1 inner CV = 75.66%)
#     Fold 3: Acc=85.00% Prec=69.23% Rec=94.74% F1=80.00% AUC=95.12%  | bobot={'w_svm': 0.271, 'w_rf': 3.0, 'w_lgbm': 0.1}
#
#   Bayesian optimization for Soft Voting base learners [Heart Failure Clinical | fold 4]
#     svm   : {'C': 0.4369339947510315, 'kernel': 'linear'}  (F1 inner CV = 68.66%)
#     rf    : {'max_depth': 3, 'n_estimators': 50}  (F1 inner CV = 75.43%)
#     lgbm  : {'learning_rate': 0.01, 'n_estimators': 374, 'num_leaves': 46}  (F1 inner CV = 75.30%)
#     Fold 4: Acc=83.33% Prec=73.68% Rec=73.68% F1=73.68% AUC=92.17%  | bobot={'w_svm': 0.372, 'w_rf': 2.044, 'w_lgbm': 2.585}
#
#   Bayesian optimization for Soft Voting base learners [Heart Failure Clinical | fold 5]
#     svm   : {'C': 22.364202820542708, 'kernel': 'linear'}  (F1 inner CV = 70.34%)
#     rf    : {'max_depth': 4, 'n_estimators': 133}  (F1 inner CV = 82.77%)
#     lgbm  : {'learning_rate': 0.01006943391489253, 'n_estimators': 344, 'num_leaves': 140}  (F1 inner CV = 79.60%)
#     Fold 5: Acc=81.36% Prec=72.22% Rec=68.42% F1=70.27% AUC=91.58%  | bobot={'w_svm': 0.1, 'w_rf': 2.591, 'w_lgbm': 0.1}
#
#   ═══ Soft Voting | SMOTE-Tomek — mean across 5 folds ═══
#   Soft Voting Ensemble     83.60% ±1.35   72.55%   79.16%   75.40%   91.33%

# %% [markdown]
# # 4. Results Summary

# %% [markdown]
# ## 4.1 F1-Score Comparison

# %%
# CELL 15 — F1-Score Comparison

all_summaries = [
    summary_va,
    summary_hf,
]

model_order = ['SVM', 'Naive Bayes', 'Random Forest', 'J48 (DecTree)',
               'Logistic Regression', 'XGBoost', 'LightGBM', 'KNN',
               'Soft Voting Ensemble']

# F1 Table
f1_table = pd.DataFrame(index=model_order,
                        columns=[s['dataset'] for s in all_summaries],
                        dtype=float)
for s in all_summaries:
    for m in model_order:
        if m in s['results']:
            f1_table.loc[m, s['dataset']] = s['results'][m]['f1'].mean() * 100

print('Mean F1-Score (%) — Nested 5-Fold CV\n')
print(f1_table.round(2).to_string())

print('\n\nBest model per dataset based on F1-Score:')
for ds in f1_table.columns:
    best_m = f1_table[ds].idxmax()
    best_v = f1_table[ds].max()
    sv_v   = f1_table.loc['Soft Voting Ensemble', ds]
    delta  = sv_v - best_v if best_m != 'Soft Voting Ensemble' else 0
    flag   = f'  (Soft Voting: {sv_v:.2f}%, difference {delta:+.2f}%)' if best_m != 'Soft Voting Ensemble' else ''
    print(f'  {ds:<25}: {best_m:<22} = {best_v:.2f}%{flag}')
# Out:
# Mean F1-Score (%) — Nested 5-Fold CV
#
#                       Hungarian  Long Beach VA  Statlog Heart  Heart Failure Clinical  Cleveland
# SVM                       76.17          80.37          82.29                   69.58      82.37
# Naive Bayes               71.87          79.23          81.54                   65.86      83.85
# Random Forest             75.34          83.65          77.95                   74.58      81.43
# J48 (DecTree)             70.17          82.16          68.75                   72.12      75.48
# Logistic Regression       76.15          78.08          81.03                   70.58      81.78
# XGBoost                   71.11          82.47          77.35                   72.30      79.87
# LightGBM                  71.88          79.89          79.40                   73.91      79.60
# KNN                       74.01          76.46          79.54                   59.35      80.59
# Soft Voting Ensemble      76.36          83.33          80.77                   73.02      82.09
#
#
# Best model per dataset based on F1-Score:
#   Hungarian                : Soft Voting Ensemble   = 76.36%
#   Long Beach VA            : Random Forest          = 83.65%  (Soft Voting: 83.33%, difference -0.32%)
#   Statlog Heart            : SVM                    = 82.29%  (Soft Voting: 80.77%, difference -1.52%)
#   Heart Failure Clinical   : Random Forest          = 74.58%  (Soft Voting: 73.02%, difference -1.57%)
#   Cleveland                : Naive Bayes            = 83.85%  (Soft Voting: 82.09%, difference -1.75%)

# %% [markdown]
# ## 4.2 Accuracy Comparison

# %%
# CELL 16 — Accuracy Comparison

acc_table = pd.DataFrame(index=model_order,
                         columns=[s['dataset'] for s in all_summaries],
                         dtype=float)
for s in all_summaries:
    for m in model_order:
        if m in s['results']:
            acc_table.loc[m, s['dataset']] = s['results'][m]['acc'].mean() * 100

print('Mean Accuracy (%) — Nested 5-Fold CV\n')
print(acc_table.round(2).to_string())
# Out:
# Mean Accuracy (%) — Nested 5-Fold CV
#
#                       Hungarian  Long Beach VA  Statlog Heart  Heart Failure Clinical  Cleveland
# SVM                       84.37           71.0          85.19                   78.60      84.48
# Naive Bayes               75.55           70.5          84.07                   78.93      85.46
# Random Forest             83.02           74.5          81.48                   83.94      84.15
# J48 (DecTree)             79.25           73.0          74.07                   81.26      77.85
# Logistic Regression       84.03           70.0          84.07                   79.28      84.14
# XGBoost                   80.29           73.0          81.11                   81.92      81.83
# LightGBM                  80.97           70.0          82.22                   82.94      82.17
# KNN                       82.99           67.5          82.59                   70.90      82.83
# Soft Voting Ensemble      84.38           74.5          83.70                   82.27      84.14

# %% [markdown]
# ## 4.3 Resampling Method Comparison

# %%
# CELL 17 — Resampling Method Comparison

def create_resampling_comparison_table(summaries):
    rows = []

    for summary in summaries:
        for resampling_label, experiment in summary.get('experiments', {}).items():
            for model_name, metrics in experiment['results'].items():
                rows.append({
                    'Dataset': summary['dataset'],
                    'Resampling Method': resampling_label,
                    'Model': model_name,
                    'Accuracy (%)': metrics['acc'].mean() * 100,
                    'Precision (%)': metrics['prec'].mean() * 100,
                    'Recall (%)': metrics['rec'].mean() * 100,
                    'F1-Score (%)': metrics['f1'].mean() * 100,
                    'AUC (%)': metrics['auc'].mean() * 100,
                    'F1 Std (%)': metrics['f1'].std() * 100,
                })

    return pd.DataFrame(rows)

resampling_comparison_table = create_resampling_comparison_table([
    summary_va,
    summary_hf,
])

print('Results for all models across resampling methods\n')
print(resampling_comparison_table.round(2).to_string(index=False))


soft_voting_resampling_table = (
    resampling_comparison_table[
        resampling_comparison_table['Model'] == 'Soft Voting Ensemble'
    ]
    .sort_values(
        by=['Dataset', 'F1-Score (%)'],
        ascending=[True, False],
    )
    .reset_index(drop=True)
)

print('\n\nResampling comparison — Soft Voting Ensemble\n')
print(soft_voting_resampling_table.round(2).to_string(index=False))


best_resampling_per_dataset = (
    soft_voting_resampling_table
    .sort_values(by=['Dataset', 'F1-Score (%)'], ascending=[True, False])
    .groupby('Dataset', as_index=False)
    .first()
)

print('\n\nBest resampling method based on F1-Score — Soft Voting Ensemble\n')
print(
    best_resampling_per_dataset[
        [
            'Dataset', 'Resampling Method',
            'Accuracy (%)', 'Precision (%)', 'Recall (%)',
            'F1-Score (%)', 'AUC (%)', 'F1 Std (%)',
        ]
    ].round(2).to_string(index=False)
)
# Out:
# Results for all models across resampling methods
#
#                Dataset Resampling Method                Model  Accuracy (%)  Precision (%)  Recall (%)  F1-Score (%)  AUC (%)  F1 Std (%)
#          Long Beach VA     No Resampling                  SVM         75.50          75.29      100.00         85.89    69.87        1.34
#          Long Beach VA     No Resampling          Naive Bayes         74.00          79.21       88.55         83.50    70.99        3.96
#          Long Beach VA     No Resampling        Random Forest         74.50          75.03       98.67         85.21    69.47        0.61
#          Long Beach VA     No Resampling        J48 (DecTree)         75.00          77.40       93.95         84.85    56.59        1.62
#          Long Beach VA     No Resampling  Logistic Regression         74.50          74.76       99.33         85.30    70.04        0.64
#          Long Beach VA     No Resampling              XGBoost         74.50          74.76       99.33         85.30    67.38        0.64
#          Long Beach VA     No Resampling             LightGBM         75.00          74.87      100.00         85.63    70.37        0.17
#          Long Beach VA     No Resampling                  KNN         78.00          79.05       95.95         86.66    71.23        1.80
#          Long Beach VA     No Resampling Soft Voting Ensemble         75.50          75.55       99.33         85.80    69.32        1.36
#          Long Beach VA             SMOTE                  SVM         71.00          80.58       80.53         80.37    67.46        3.45
#          Long Beach VA             SMOTE          Naive Bayes         70.50          83.13       75.86         79.23    67.38        3.18
#          Long Beach VA             SMOTE        Random Forest         74.50          79.62       88.60         83.65    67.14        4.33
#          Long Beach VA             SMOTE        J48 (DecTree)         73.00          80.52       84.57         82.16    61.70        3.50
#          Long Beach VA             SMOTE  Logistic Regression         70.00          85.13       72.48         78.08    67.85        5.25
#          Long Beach VA             SMOTE              XGBoost         73.00          80.18       85.29         82.47    67.76        0.96
#          Long Beach VA             SMOTE             LightGBM         70.00          78.83       81.93         79.89    62.64        6.21
#          Long Beach VA             SMOTE                  KNN         67.50          83.15       71.15         76.46    65.78        3.27
#          Long Beach VA             SMOTE Soft Voting Ensemble         74.50          80.71       86.60         83.33    67.55        3.85
#          Long Beach VA  Borderline-SMOTE                  SVM         72.00          82.29       79.82         80.83    68.79        2.75
#          Long Beach VA  Borderline-SMOTE          Naive Bayes         70.00          82.69       75.79         78.83    69.08        3.65
#          Long Beach VA  Borderline-SMOTE        Random Forest         74.50          81.06       85.86         83.16    68.76        4.56
#          Long Beach VA  Borderline-SMOTE        J48 (DecTree)         65.50          80.87       71.17         75.47    60.81        4.50
#          Long Beach VA  Borderline-SMOTE  Logistic Regression         68.50          84.83       70.41         76.74    69.96        4.44
#          Long Beach VA  Borderline-SMOTE              XGBoost         71.50          79.46       83.95         81.28    65.16        3.12
#          Long Beach VA  Borderline-SMOTE             LightGBM         71.50          80.79       81.22         80.93    68.29        2.03
#          Long Beach VA  Borderline-SMOTE                  KNN         65.00          82.11       67.77         74.24    64.61        3.20
#          Long Beach VA  Borderline-SMOTE Soft Voting Ensemble         73.00          81.18       83.22         82.01    69.00        2.95
#          Long Beach VA       SMOTE-Tomek                  SVM         71.00          80.97       79.86         80.32    70.14        3.74
#          Long Beach VA       SMOTE-Tomek          Naive Bayes         70.50          83.85       75.84         79.09    70.80        3.06
#          Long Beach VA       SMOTE-Tomek        Random Forest         74.50          80.75       86.55         83.33    68.01        4.00
#          Long Beach VA       SMOTE-Tomek        J48 (DecTree)         68.50          81.71       74.46         77.68    65.21        5.47
#          Long Beach VA       SMOTE-Tomek  Logistic Regression         70.50          85.97       72.46         78.35    69.49        4.93
#          Long Beach VA       SMOTE-Tomek              XGBoost         73.50          80.63       85.26         82.58    63.76        3.79
#          Long Beach VA       SMOTE-Tomek             LightGBM         71.00          79.80       81.91         80.78    69.91        3.28
#          Long Beach VA       SMOTE-Tomek                  KNN         64.00          82.35       65.79         72.98    68.27        4.55
#          Long Beach VA       SMOTE-Tomek Soft Voting Ensemble         73.50          80.22       85.91         82.73    71.65        3.03
# Heart Failure Clinical     No Resampling                  SVM         82.26          78.13       62.42         69.22    86.64        5.01
# Heart Failure Clinical     No Resampling          Naive Bayes         77.59          74.43       46.89         57.45    85.15        4.98
# Heart Failure Clinical     No Resampling        Random Forest         83.26          76.64       68.68         72.13    89.82        8.80
# Heart Failure Clinical     No Resampling        J48 (DecTree)         80.94          73.31       65.42         68.05    85.44        7.18
# Heart Failure Clinical     No Resampling  Logistic Regression         83.59          78.61       67.74         72.55    87.54        7.91
# Heart Failure Clinical     No Resampling              XGBoost         82.94          75.76       68.74         71.86    90.31        7.86
# Heart Failure Clinical     No Resampling             LightGBM         84.94          80.83       69.74         74.61    90.69        5.23
# Heart Failure Clinical     No Resampling                  KNN         70.90          58.80       32.21         40.98    74.44        9.06
# Heart Failure Clinical     No Resampling Soft Voting Ensemble         84.60          79.50       69.74         74.07    90.83        6.92
# Heart Failure Clinical             SMOTE                  SVM         78.60          65.05       76.05         69.58    87.34        1.54
# Heart Failure Clinical             SMOTE          Naive Bayes         78.93          69.69       63.63         65.86    84.18        5.83
# Heart Failure Clinical             SMOTE        Random Forest         83.94          75.72       73.89         74.58    90.70        4.29
# Heart Failure Clinical             SMOTE        J48 (DecTree)         81.26          69.42       75.95         72.12    82.61        3.94
# Heart Failure Clinical             SMOTE  Logistic Regression         79.28          65.83       77.11         70.58    87.59        2.48
# Heart Failure Clinical             SMOTE              XGBoost         81.92          70.45       74.84         72.30    89.29        8.34
# Heart Failure Clinical             SMOTE             LightGBM         82.94          72.57       76.89         73.91    90.09        4.82
# Heart Failure Clinical             SMOTE                  KNN         70.90          53.66       66.58         59.35    77.89        8.69
# Heart Failure Clinical             SMOTE Soft Voting Ensemble         82.27          71.71       74.95         73.02    89.07        2.67
# Heart Failure Clinical  Borderline-SMOTE                  SVM         79.61          66.21       78.11         71.18    87.68        1.95
# Heart Failure Clinical  Borderline-SMOTE          Naive Bayes         79.27          69.96       67.74         68.04    83.32        4.10
# Heart Failure Clinical  Borderline-SMOTE        Random Forest         82.93          72.22       76.00         73.94    90.19        4.76
# Heart Failure Clinical  Borderline-SMOTE        J48 (DecTree)         78.94          64.87       76.95         70.01    82.43        5.33
# Heart Failure Clinical  Borderline-SMOTE  Logistic Regression         79.61          66.14       78.11         71.16    86.95        1.72
# Heart Failure Clinical  Borderline-SMOTE              XGBoost         82.27          71.46       74.95         72.98    88.33        4.02
# Heart Failure Clinical  Borderline-SMOTE             LightGBM         83.27          72.65       76.95         74.42    90.46        5.09
# Heart Failure Clinical  Borderline-SMOTE                  KNN         69.57          52.37       64.53         57.70    77.99        6.01
# Heart Failure Clinical  Borderline-SMOTE Soft Voting Ensemble         83.28          72.30       78.11         74.91    91.19        3.70
# Heart Failure Clinical       SMOTE-Tomek                  SVM         78.25          65.81       72.95         68.50    86.25        5.37
# Heart Failure Clinical       SMOTE-Tomek          Naive Bayes         78.25          69.69       61.47         64.58    83.28        6.38
# Heart Failure Clinical       SMOTE-Tomek        Random Forest         86.28          77.85       80.16         78.71    90.59        4.88
# Heart Failure Clinical       SMOTE-Tomek        J48 (DecTree)         79.93          65.04       83.21         72.58    81.78        2.66
# Heart Failure Clinical       SMOTE-Tomek  Logistic Regression         79.60          65.48       79.16         71.34    86.20        1.83
# Heart Failure Clinical       SMOTE-Tomek              XGBoost         83.60          73.81       75.89         74.49    89.89        6.89
# Heart Failure Clinical       SMOTE-Tomek             LightGBM         82.61          73.54       72.95         72.92    89.07        2.08
# Heart Failure Clinical       SMOTE-Tomek                  KNN         71.90          55.59       69.89         61.66    78.39        4.90
# Heart Failure Clinical       SMOTE-Tomek Soft Voting Ensemble         83.60          72.55       79.16         75.40    91.33        3.39
#
#
# Resampling comparison — Soft Voting Ensemble
#
#                Dataset Resampling Method                Model  Accuracy (%)  Precision (%)  Recall (%)  F1-Score (%)  AUC (%)  F1 Std (%)
# Heart Failure Clinical       SMOTE-Tomek Soft Voting Ensemble         83.60          72.55       79.16         75.40    91.33        3.39
# Heart Failure Clinical  Borderline-SMOTE Soft Voting Ensemble         83.28          72.30       78.11         74.91    91.19        3.70
# Heart Failure Clinical     No Resampling Soft Voting Ensemble         84.60          79.50       69.74         74.07    90.83        6.92
# Heart Failure Clinical             SMOTE Soft Voting Ensemble         82.27          71.71       74.95         73.02    89.07        2.67
#          Long Beach VA     No Resampling Soft Voting Ensemble         75.50          75.55       99.33         85.80    69.32        1.36
#          Long Beach VA             SMOTE Soft Voting Ensemble         74.50          80.71       86.60         83.33    67.55        3.85
#          Long Beach VA       SMOTE-Tomek Soft Voting Ensemble         73.50          80.22       85.91         82.73    71.65        3.03
#          Long Beach VA  Borderline-SMOTE Soft Voting Ensemble         73.00          81.18       83.22         82.01    69.00        2.95
#
#
# Best resampling method based on F1-Score — Soft Voting Ensemble
#
#                Dataset Resampling Method  Accuracy (%)  Precision (%)  Recall (%)  F1-Score (%)  AUC (%)  F1 Std (%)
# Heart Failure Clinical       SMOTE-Tomek          83.6          72.55       79.16          75.4    91.33        3.39
#          Long Beach VA     No Resampling          75.5          75.55       99.33          85.8    69.32        1.36
